# %%
from langserve import RemoteRunnable

# ngrok remote 주소 설정

chain = RemoteRunnable("NGROK 에서 설정한 본인의 도메인 주소/prompt/")
# chain = RemoteRunnable("https://poodle-deep-marmot.ngrok-free.app/prompt/")
# chain = RemoteRunnable("http://0.0.0.0:8000/prompt/")

for token in chain.stream({"topic": "딥러닝에 대해서 알려줘"}):
    print(token, end="")
# Out:
# 딥러닝은 인공지능(AI)의 한 분야로, 인간 두뇌의 정보 처리 능력을 모방한 신경망인 뉴럴 네트워크를 사용하여 대량의 데이터를 학습하고 복잡한 패턴을 인식하며 예측을 하는 것을 말합니다. 인간의 뇌에서 영감을 받은 이러한 고급 기계학습 알고리즘들은 이미지 및 음성 인식, 자연어 처리, 자율 주행 차량, 의료 진단 등 다양한 분야에서 큰 성공을 거두었습니다.
#
# 딥러닝은 여러 층의 뉴런으로 구성된 다층 신경망(DNNs)을 활용하는 것을 특징으로 합니다. 이 네트워크는 데이터로부터 학습할수록 점점 더 정확해지는 '딥' 구조를 가집니다. 전통적인 머신러닝 알고리즘과 달리, 딥러닝 모델들은 인간에 의해 수작업적으로 정의되지 않고 데이터에서 직접 추출되는 특징들을 가지고 있습니다. 이를 통해 대량의 데이터셋을 다룰 때 더욱 유연한 접근 방식을 가능하게 합니다.
#
# 딥러닝의 주요 구성 요소 및 개념은 다음과 같습니다:
#
# 1. 뉴럴 네트워크(NNs): 인공 신경세포로 이루어진 계층적 구조로, 인간의 뇌에서 영감을 받은 정보 처리 방식입니다. 입력 신호는 첫 번째 층에서 처리되고 출력 신호를 생성합니다.
# 2. 다층 퍼셉트론(MLP): 여러 개의 은닉층을 가진 뉴럴 네트워크의 한 유형으로, 각 은닉층은 이전 레이어의 출력을 입력으로 받습니다.
# 3. 컨볼루션 신경망(CNNs): 이미지 및 비디오 분석에 특화되어 있으며, 컨볼루션과 풀링이라는 두 가지 주요 연산자를 사용하여 특징 추출을 수행합니다. 이 모델들은 시각 인식 작업에서 성공을 거두었습니다.
# 4. 순환 신경망(RNNs) 및 장단기 기억(LSTM): 시계열 데이터를 처리하는 데 적합하며, 과거 정보를 기억하고 시간에 따른 패턴을 학습할 수 있습니다. 이는 자연어 처리와 신호 분석과 같은 응용 분야에서 사용되었습니다.
# 5. 생성적 적대 신경망(GANs): 한 네트워크가 진짜와 구별할 수 없는 이미지를 생성하도록 다른 네트워크를 속이는 경쟁 과정을 통해 작동합니다. 이 모델들은 이미지 및 영상 합성, 컴퓨터 그래픽 등에서 활용되고 있습니다.
# 6. 트랜스포머: 자연어 처리(NLP) 작업을 위해 설계된 아키텍처로, 시퀀스 간 비선형 상호작용을 가능하게 하는 주의 메커니즘에 의존합니다. 이 모델들은 기계 번역과 요약에서 강력한 성능을 보여주었습니다.
# 7. 강화학습(RL): 딥러닝의 한 분야로, 환경과 상호 작용하면서 보상 신호를 통해 행동을 조정함으로써 학습하는 알고리즘입니다. RL은 자율 주행 차량 및 비디오 게임에서의 에이전트 제어에 활용되었습니다.
# 8. 앙상블 방법: 여러 모델을 결합하여 예측 성능을 향상시키는 기법들(예: 투표, 부스팅)로, 모델의 다양성과 안정성을 증가시키며 과적합 가능성을 줄입니다.
#
# 요약하자면, 딥러닝은 대량의 데이터에서 복잡한 패턴을 인식하고 학습할 수 있는 고급 머신러닝 알고리즘으로, 다양한 분야에서 인간 의사결정 능력에 근접하는 결과를 달성했습니다. 뉴럴 네트워크와 그 응용을 통해 계속해서 발전하고 있으며, 우리 주변 세계를 이해하고 자동화하는 데 있어 새로운 가능성을 열어주고 있습니다.
